# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Steps for data anlysis
#  Data prepartion - Model Training -Model Optimization -Model Evaluation
#   In data Prepartion
#        Data manipulation is the process of organizing data to make it more understandable.1 It involves adding, deleting, and updating                               data in a database using a computer programming language called data manipulation language (DML)
#        Data blending merging to csv files
#        Missing values handling here added with mean value
#        Feature generation depended variables
#        Dimensionality Reduction done by using Heatmap to reduce depend variables
#        Feature selection reduced feature that are more in

# %%
df = pd.read_csv(r'C:\Users\manas\OneDrive\Desktop\python\water_potability.csv')

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# DATA CLEANING

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# FILLING DATA WITH MEAN VALUE

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df.fillna(df.mean(),inplace= True)

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
#we have 9 feature(ph Hardness Solids Chloramines Sulfate Conductivity	Organic_carbon	Trihalomethanes	Turbidity) and 1 target value(Potability)

# %% [markdown]
# CHECKING IF WE NEED TO DO DIMENSONILITY REDUCTION

# %%
sns.heatmap(df.corr(),annot =True,cmap ="terrain")
fig = plt.gcf()
fig.set_size_inches(11,7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Checking the outlier Box Plot

# %%
df.boxplot(figsize=(15,6))
plt.show()

# %%
df['Solids'].describe()
# Out:
# count     3276.000000
# mean     22014.092526
# std       8768.570828
# min        320.942611
# 25%      15666.690297
# 50%      20927.833607
# 75%      27332.762127
# max      61227.196008
# Name: Solids, dtype: float64

# %%
df['Solids']
# Out:
# 0       20791.318981
# 1       18630.057858
# 2       19909.541732
# 3       22018.417441
# 4       17978.986339
#             ...
# 3271    47580.991603
# 3272    17329.802160
# 3273    33155.578218
# 3274    11983.869376
# 3275    17404.177061
# Name: Solids, Length: 3276, dtype: float64

# %%
#not romoving  the solid outliers because they are giving data of bad water i.e major factor

# %% [markdown]
# Label Encoding is a technique that is used to convert categorical columns into numerical ones so that they can be fitted by machine learning models which only take numerical data. It is an important pre-processing step in a machine-learning project. Suppose we have a column Height in some dataset that has elements as Tall, Medium, and short. To convert this categorical column into a numerical column we will apply label encoding to this column.

# %%
df['Potability'].value_counts()
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
sns.countplot(df['Potability'])
plt.show()

# %%
df.hist(figsize=(14,12))
plt.show()

# %%
sns.barplot(x=df['ph'],y=df['Hardness'] , hue = df['Potability'])
plt.show()

# %%
sns.scatterplot(x=df['Solids'],y=df['Potability'])
plt.show()

# %%
sns.scatterplot(x=df['ph'],y=df['Potability'])
# Out:
# <Axes: xlabel='ph', ylabel='Potability'>

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
X = df.drop('Potability', axis = 1)

# %%
Y = df['Potability']
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y ,test_size = 0.2,shuffle = True , random_state = None)

# %%
X_train
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2131  7.191962  228.409943  15395.469082     7.398603  334.777619
# 547   7.510943  182.192847  17100.887433     5.948785  357.265732
# 762   5.225684  185.050444  16276.398604     6.617098  333.775777
# 1788  7.436537  167.328466  31935.690705     7.896365  333.775777
# 305   6.428866  225.613094  15596.473334     6.153472  333.775777
# ...        ...         ...           ...          ...         ...
# 249   6.755146  231.260131  18536.698647     8.757133  342.548014
# 1702  4.221421  120.560130  34370.197113     7.960888  411.580830
# 2366  8.646643  201.439065  32571.054518     9.959355  333.775777
# 5     5.584087  188.313324  28748.687739     7.544869  326.678363
# 860   8.783168  218.032840  16183.586649     7.390474  334.053885
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 2131    294.915584       13.932293        50.748365   4.102719
# ...

# %% [markdown]
# MODEL TRAINING

# %% [raw]
# #
